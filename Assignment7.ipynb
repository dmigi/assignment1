# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#question 1
df= pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv')
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
#question2
df.isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# 5      False  False  False     False      False        False     False
# 6      False  False  False     False      False        False     False
# 7      False  False  False     False      False        False     False
# 8      False  False  False     False      False        False     False
# 9      False  False  False     False      False        False     False
# 10     False  False  False     False      False        False     False
# 11     False  False  False     False      False        False     False
# ...

# %%
plt.plot(df['bathrooms'],df['waterfront']) #question4

# %%
sns.boxplot(x='bathrooms', y='sqft_living',data=df.head(20)) #question4

# %%
plt.hist(df['bathrooms']) #question3
# Out:
# (array([8.600e+01, 5.307e+03, 7.025e+03, 7.318e+03, 1.475e+03, 3.380e+02,
#         4.400e+01, 1.200e+01, 4.000e+00, 4.000e+00]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. , 4.8, 5.6, 6.4, 7.2, 8. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(df['floors'],kde=True) #question3

# %%
sns.kdeplot(df['sqft_living']) #question3

# %%
sns.boxplot(df['sqft_living'])

# %%
sns.jointplot (df['price'], df['sqft_living'],kind='hex',color='r') #qestion4

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.jointplot (df['sqft_living'], df['price'],kind='kde',color='g') #question5

# %%
df.bedrooms.unique
# Out:
# <bound method Series.unique of 0        3
# 1        3
# 2        2
# 3        4
# 4        3
# 5        4
# 6        3
# 7        3
# 8        3
# 9        3
# 10       3
# 11       2
# 12       3
# 13       3
# 14       5
# 15       4
# 16       3
# 17       4
# 18       2
# 19       3
# 20       4
# 21       3
# 22       5
# 23       2
# 24       3
# 25       3
# 26       3
# 27       3
# 28       3
# 29       4
#         ..
# 21583    2
# 21584    3
# 21585    3
# 21586    2
# 21587    3
# 21588    2
# 21589    3
# 21590    4
# 21591    4
# 21592    3
# 21593    5
# 21594    4
# 21595    2
# 21596    5
# 21597    4
# 21598    4
# 21599    4
# 21600    5
# 21601    3
# 21602    3
# 21603    3
# 21604    3
# 21605    4
# 21606    4
# 21607    3
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64>

# %%
sns.distplot(df['sqft_living'],kde=True)

# %%
plt.figure(figsize=(10,7))
sns.stripplot(x='price', y='sqft_living',data=df)

# %%
sns.swarmplot(x='bedrooms', y='sqft_living',data=df.head(20))

# %%
plt.figure(figsize=(10,8)) #question5
corr=df.corr()
sns.heatmap(corr)

# %%
sns.countplot(x='price', data=df.head(10))

# %%
var=df.head(20)
sns.pairplot(var) #question5

# %%
#question 6
1)heatmap
2)striplot gives direct relationship between price and sqft_living
